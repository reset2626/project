# %% [markdown]
# # 2026 Time Series Final Project
#
# ## Problem 1：ARIMA model and Kalman Filter
#
# `Dataset-Stock.txt`，資料內容為 Alcoa 股票報酬率所計算出的日實現波動率。
#
# 在開始建立 local trend model 與 Kalman filter 之前，先對資料做基本檢查，包括：
#
# 1. 讀取資料並確認資料格式。
# 2. 檢查資料筆數與缺失值。
# 3. 計算描述統計量。
# 4. 繪製時間序列圖、直方圖與盒鬚圖，初步觀察資料分布與可能的極端值。

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["font.sans-serif"] = ["Microsoft JhengHei"]
plt.rcParams["axes.unicode_minus"] = False

# %% [markdown]
# ## 1. 讀取資料
#
# 由於 `Dataset-Stock.txt` 為單欄數值資料，且檔案中沒有欄名，因此讀取時需設定 `header=None`，再自行命名欄位。這裡將波動率欄位命名為 `rv`（realized volatility）。

# %%
stock_path = r"c:\Users\allen\OneDrive\Desktop\研究所\時序\Dataset-Stock.txt"

stock_df = pd.read_csv(stock_path, header=None, names=["rv"])
stock_df.head()
# Out:
#         rv
# 0   3.0692
# 1   6.7121
# 2   0.5711
# 3   2.1220
# 4  14.5181

# %% [markdown]
# ## 2. 基本資料檢查
#
# 這一步先確認：
#
# - 總共有多少筆觀測值。
# - 是否存在缺失值。
# - 欄位型態是否正確。
# - 資料的大致集中位置與離散程度。

# %%
print("資料筆數：", stock_df.shape[0])
print("欄位數：", stock_df.shape[1])
print("缺失值個數：")
print(stock_df.isna().sum())
print("\n欄位型態：")
print(stock_df.dtypes)
print("\n描述統計量：")
print(stock_df.describe())
# Out:
# 資料筆數： 340
# 欄位數： 1
# 缺失值個數：
# rv    0
# dtype: int64
#
# 欄位型態：
# rv    float64
# dtype: object
#
# 描述統計量：
#                rv
# count  340.000000
# mean     2.872898
# std      2.320472
# min      0.266900
# 25%      1.520525
# 50%      2.333450
# 75%      3.432825
# max     28.153400

# %% [markdown]
# ### 基本檢查說明
#
# 從基本檢查可先確認此資料為單一數值型欄位，且沒有缺失值，因此可直接進入後續分析。描述統計量則有助於初步了解資料的平均數、中位數、標準差，以及是否可能存在明顯偏態或極端值。

# %% [markdown]
# ## 3. 視覺化檢查
#
# 由於原始資料檔中只有波動率數值，沒有另外附日期欄，因此這裡先以觀測次序作為橫軸。這樣仍可用來觀察資料是否存在波動群聚、尖峰值，以及整體分布情形。

# %%
fig, axes = plt.subplots(3, 1, figsize=(10, 12))

axes[0].plot(stock_df.index, stock_df["rv"], color="steelblue")
axes[0].set_title("Alcoa 日實現波動率時間序列圖")
axes[0].set_xlabel("觀測次序")
axes[0].set_ylabel("Realized Volatility")
axes[0].grid(True)

axes[1].hist(stock_df["rv"], bins=30, color="slateblue", edgecolor="white")
axes[1].set_title("實現波動率直方圖")
axes[1].set_xlabel("Realized Volatility")
axes[1].set_ylabel("Frequency")
axes[1].grid(True)

axes[2].boxplot(stock_df["rv"], vert=True)
axes[2].set_title("實現波動率盒鬚圖")
axes[2].set_ylabel("Realized Volatility")
axes[2].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 視覺化說明
#
# 時間序列圖可用來觀察波動率是否有明顯的高低波動區段。直方圖可幫助判斷資料分布是否偏態，而盒鬚圖則有助於辨識極端值。這些初步觀察將作為後續建立 state-space model 與 Kalman filter 的參考。

# %% [markdown]
# ## (a) 估計 local trend model
#
# 根據題目與投影片中的 Equations (11.1) 與 (11.2)，本題採用下列 local trend model：
#
# $$y_t = \mu_t + e_t, \qquad e_t \sim N(0, \sigma_e^2)$$
#
# $$\mu_{t+1} = \mu_t + \eta_t, \qquad \eta_t \sim N(0, \sigma_\eta^2)$$
#
# 其中，$y_t$ 為觀察到的實現波動率 $\mu_t$ 為不可觀測的潛在趨勢，$e_t$ 為觀測誤差，$\eta_t$ 為狀態誤差。

# %%
from statsmodels.tsa.statespace.structural import UnobservedComponents

local_trend_model = UnobservedComponents(stock_df["rv"], level="local level")
local_trend_result = local_trend_model.fit(disp=False)

print(local_trend_result.summary())
local_trend_result.params
# Out:
#                         Unobserved Components Results
# ...
# Dep. Variable:                     rv   No. Observations:                  340
# Model:                    local level   Log Likelihood                -761.211
# Date:                Mon, 25 May 2026   AIC                           1526.422
# Time:                        19:06:55   BIC                           1534.074
# Sample:                             0   HQIC                          1529.472
#                                 - 340
# Covariance Type:                  opg
# ...
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# sigma2.irregular     4.8951      0.135     36.130      0.000       4.630       5.161
# sigma2.level         0.0166      0.015      1.138      0.255      -0.012       0.045
# ...
# Ljung-Box (L1) (Q):                   0.53   Jarque-Bera (JB):             39272.63
# ...

# %% [markdown]
# ### (a) 結果說明
#
# 利用 local trend model 估計後，可得到觀測誤差變異數與狀態誤差變異數的估計值。根據目前的估計結果：
#
# - $\sigma_e^2 = 4.8951$
# - $\sigma_\eta^2 = 0.0166$
#
# 因此，估計後的模型可寫為：
#
# $y_t = \mu_t + e_t, \qquad e_t \sim N(0, 4.8951)$
#
# $\mu_{t+1} = \mu_t + \eta_t, \qquad \eta_t \sim N(0, 0.0166)$
#
# 由估計值可看出，觀測誤差的變異遠大於狀態誤差，表示資料中的短期波動相對明顯，而潛在趨勢本身隨時間變動得較為平滑。

# %% [markdown]
# ## (b) Filtered variables 與 95% 信賴區間
#
# filtered variable 指的是在觀測到第 `t` 期資料後，對當期潛在狀態的估計值。在 local trend model 中，潛在狀態為 $\mu_t$，因此 filtered variable 的數學表示為：
#
# $\mu_{t|t} = E(\mu_t \mid y_1, y_2, \ldots, y_t)$
#
# pointwise 95% confidence interval 可表示為：
#
# $\mu_{t|t} \pm 1.96\sqrt{P_{t|t}}$
#
# 其中，$P_{t|t}$ 為 filtered state estimate 的變異數。

# %%
filtered_mean = pd.Series(local_trend_result.filtered_state[0], index=stock_df.index)
filtered_var = pd.Series(local_trend_result.filtered_state_cov[0, 0], index=stock_df.index)
filtered_se = np.sqrt(filtered_var)

filtered_df = pd.DataFrame({
    "rv": stock_df["rv"],
    "filtered_mean": filtered_mean,
    "filtered_lower": filtered_mean - 1.96 * filtered_se,
    "filtered_upper": filtered_mean + 1.96 * filtered_se
})

filtered_df.head()
# Out:
#         rv  filtered_mean  filtered_lower  filtered_upper
# 0   3.0692       3.069185       -1.267299        7.405669
# 1   6.7121       4.893726        1.824767        7.962686
# 2   0.5711       3.444722        0.933993        5.955451
# 3   2.1220       3.110130        0.929098        5.291162
# 4  14.5181       5.437878        3.479022        7.396735

# %%
plt.figure(figsize=(12, 5))
plt.plot(filtered_df.index, filtered_df["rv"], color="lightgray", label="Observed volatility")
plt.plot(filtered_df.index, filtered_df["filtered_mean"], color="darkblue", label="Filtered state")
plt.fill_between(
    filtered_df.index,
    filtered_df["filtered_lower"],
    filtered_df["filtered_upper"],
    color="skyblue",
    alpha=0.3,
    label="95% CI"
)
plt.title("Filtered state estimates with 95% confidence interval")
plt.xlabel("觀測次序")
plt.ylabel("State / Volatility")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### (b) 結果說明
#
# 此圖呈現 Kalman filter 對每一期潛在趨勢 $\mu_t$ 的 filtered estimate $\mu_{t|t}$。
# 表示在觀測到第 $t$ 期資料後，對當期狀態所做的即時估計。
#
# 由圖可見，filtered state 能夠追蹤波動率資料的整體變化方向，但相較於原始觀測值更為平滑，因為 Kalman filter 會同時考慮狀態演化方程與觀測誤差。圖中的陰影區域為 pointwise 95% confidence interval，用來表示各期 filtered estimate 的不確定性範圍。

# %% [markdown]
# ## (c) Smoothed variables 與 95% 信賴區間
#
# smoothed variable 指的是在使用完整樣本資訊 $y_1, y_2, \ldots, y_T$ 後，對第 $t$ 期潛在狀態的估計值。local trend model 中，smoothed variable 的數學表示為：
#
# $\mu_{t|T} = E(\mu_t \mid y_1, y_2, \ldots, y_T)$
#
# 這和 filtered variable $\mu_{t|t}$ 的差別在於，smoothed estimate 不只使用當期以前的資訊，而是使用整段樣本資料回頭估計每一期的狀態。
#
# 其 pointwise 95% confidence interval 可表示為：
#
# $\mu_{t|T} \pm 1.96\sqrt{P_{t|T}}$
#
# 其中，$P_{t|T}$ 為 smoothed state estimate 的變異數。

# %%
smoothed_mean = pd.Series(local_trend_result.smoothed_state[0], index=stock_df.index)
smoothed_var = pd.Series(local_trend_result.smoothed_state_cov[0, 0], index=stock_df.index)
smoothed_se = np.sqrt(smoothed_var)

smoothed_df = pd.DataFrame({
    "rv": stock_df["rv"],
    "smoothed_mean": smoothed_mean,
    "smoothed_lower": smoothed_mean - 1.96 * smoothed_se,
    "smoothed_upper": smoothed_mean + 1.96 * smoothed_se
})

smoothed_df.head()
# Out:
#         rv  smoothed_mean  smoothed_lower  smoothed_upper
# 0   3.0692       4.072538        3.040777        5.104300
# 1   6.7121       4.075947        3.072113        5.079780
# 2   0.5711       4.070400        3.092093        5.048708
# 3   2.1220       4.076741        3.121724        5.031757
# 4  14.5181       4.089721        3.155922        5.023519

# %%
plt.figure(figsize=(12, 5))
plt.plot(smoothed_df.index, smoothed_df["rv"], color="lightgray", label="Observed volatility")
plt.plot(smoothed_df.index, smoothed_df["smoothed_mean"], color="darkred", label="Smoothed state")
plt.fill_between(
    smoothed_df.index,
    smoothed_df["smoothed_lower"],
    smoothed_df["smoothed_upper"],
    color="mistyrose",
    alpha=0.4,
    label="95% CI"
)
plt.title("Smoothed state estimates with 95% confidence interval")
plt.xlabel("觀測次序")
plt.ylabel("State / Volatility")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### (c) 結果說明
#
# 此圖呈現 smoothed state estimate，也就是 $\mu_{t|T}$。它表示：在使用完整樣本資料後，回頭對每一期潛在趨勢所做的估計。
#
# 由於 smoothed estimate 使用了全樣本資訊，因此相較於 filtered estimate，通常會更平滑，也更能呈現整體趨勢變化。圖中的陰影區域為 pointwise 95% confidence interval，用來表示各期 smoothed estimate 的不確定性範圍。

# %% [markdown]
# # Problem 2：Gibbs Sampling and Markov Switching Model
#
# 本題使用 `Data-GEstock.txt`，資料內容為 GE 股票自 1926 年至 1999 年的月 log return。
#
# 依照題目與投影片中的 Equations (12.55) 與 (12.56)，考慮二狀態 Markov switching GARCH-M model：
#
# $r_t = \beta_1\sqrt{h_t} + \sqrt{h_t}\varepsilon_t, \quad h_t = \alpha_{10} + \alpha_{11}h_{t-1} + \alpha_{12}a_{t-1}^2 \quad \text{if } s_t=1$
#
# $r_t = \beta_2\sqrt{h_t} + \sqrt{h_t}\varepsilon_t, \quad h_t = \alpha_{20} + \alpha_{21}h_{t-1} + \alpha_{22}a_{t-1}^2 \quad \text{if } s_t=2$
#
# 其中狀態轉移機率為：
#
# $P(s_t=2\mid s_{t-1}=1)=e_1, \qquad P(s_t=1\mid s_{t-1}=2)=e_2$
#
# 以下將依序進行：
#
# 1. 資料讀取與基本檢查。
# 2. 以 Gibbs sampling 建立 Bayesian 估計。
# 3. 繪製 volatility parameters 的後驗分布（對應 Figure 12.16）。
# 4. 呈現 state 2 的後驗機率。
# 5. 以 frequentist / EM 類方法作為 Baum-Welch benchmark。
# 6. 根據 state 2 的後驗機率推論各期狀態。

# %%
ge_path = r"c:\Users\allen\OneDrive\Desktop\研究所\時序\Data-GEstock.txt"

ge_df = pd.read_csv(ge_path, header=None, names=["r"])
ge_df["date"] = pd.date_range("1926-01-01", periods=len(ge_df), freq="MS")
ge_df = ge_df.set_index("date")

print("資料筆數：", ge_df.shape[0])
print("缺失值個數：")
print(ge_df.isna().sum())
print("\n描述統計量：")
print(ge_df.describe())
ge_df.head()
# Out:
# 資料筆數： 888
# 缺失值個數：
# r    0
# dtype: int64
#
# 描述統計量：
#                 r
# count  888.000000
# mean     1.037578
# std      7.744727
# min    -43.872000
# 25%     -3.262750
# 50%      0.902000
# 75%      5.417750
# max     44.469000
#                 r
# date
# 1926-01-01  4.204
# 1926-02-01 -0.590
# 1926-03-01 -9.376
# 1926-04-01  5.450
# 1926-05-01 -0.894

# %% [markdown]
# ## (a) Gibbs sampling 估計後驗分布
#
# 此處依照投影片 page 66 的做法，對 volatility parameters 採用 Griddy Gibbs 更新，對轉移機率 $e_1, e_2$ 採用 Beta 共軛後驗更新。對於隱含狀態序列 $S$，則以單點 Gibbs 更新，並在每次更新時重新計算 suffix likelihood。
#
# 這裡改採較完整的 Gibbs 設定：每次 iteration 都更新整條 state path，並使用較長的 chain 與較細的 parameter grid。因此執行時間會比前一版明顯增加，但結果會更接近正常的 posterior simulation。
#
# 另外，為了降低兩個 regime 在抽樣過程中發生 label switching 的影響，這裡額外根據各 regime 的長期變異數大小進行重新標記，使 state 2 盡量對應到較高波動的 regime。

# %%
import math
from scipy.stats import beta as beta_dist
from statsmodels.tsa.regime_switching.markov_regression import MarkovRegression

r = ge_df["r"].to_numpy()
T = len(r)
h0 = float(np.var(r))
a0 = 0.0

def get_state_params(s, p):
    if s == 0:
        return p["beta1"], p["a10"], p["a11"], p["a12"]
    return p["beta2"], p["a20"], p["a21"], p["a22"]

def transition_matrix(p):
    e1 = min(max(float(p["e1"]), 1e-4), 1 - 1e-4)
    e2 = min(max(float(p["e2"]), 1e-4), 1 - 1e-4)
    return np.array([[1 - e1, e1], [e2, 1 - e2]])

def forward_recursion(states, p):
    h = np.zeros(T)
    a = np.zeros(T)
    ll = 0.0
    P = transition_matrix(p)
    prev_h = h0
    prev_a = a0
    for t in range(T):
        s = int(states[t])
        beta_i, a0_i, a1_i, a2_i = get_state_params(s, p)
        h[t] = max(a0_i + a1_i * prev_h + a2_i * (prev_a ** 2), 1e-6)
        mean_t = beta_i * np.sqrt(h[t])
        a[t] = r[t] - mean_t
        ll += -0.5 * (np.log(h[t]) + (a[t] ** 2) / h[t])
        ll += np.log(0.5 if t == 0 else P[int(states[t - 1]), s] + 1e-12)
        prev_h = h[t]
        prev_a = a[t]
    return h, a, ll

def suffix_loglik(start, states, p, h, a):
    P = transition_matrix(p)
    h_new = h.copy()
    a_new = a.copy()
    ll = 0.0
    prev_h = h0 if start == 0 else h_new[start - 1]
    prev_a = a0 if start == 0 else a_new[start - 1]
    for t in range(start, T):
        s = int(states[t])
        beta_i, a0_i, a1_i, a2_i = get_state_params(s, p)
        h_new[t] = max(a0_i + a1_i * prev_h + a2_i * (prev_a ** 2), 1e-6)
        mean_t = beta_i * np.sqrt(h_new[t])
        a_new[t] = r[t] - mean_t
        ll += -0.5 * (np.log(h_new[t]) + (a_new[t] ** 2) / h_new[t])
        ll += np.log(0.5 if t == 0 else P[int(states[t - 1]), s] + 1e-12)
        prev_h = h_new[t]
        prev_a = a_new[t]
    return h_new, a_new, ll

def sample_beta(states, h, params, which, rng):
    key = "beta1" if which == 0 else "beta2"
    idx = np.where(states == which)[0]
    if len(idx) == 0:
        return params[key]
    x = np.sqrt(np.maximum(h[idx], 1e-8))
    y = r[idx] / x
    v0 = 100.0
    post_var = 1.0 / (1.0 / v0 + len(idx))
    post_mean = post_var * y.sum()
    return float(rng.normal(post_mean, math.sqrt(post_var)))

def full_loglik_given(states, p):
    return forward_recursion(states, p)[2]

def sample_alpha_grid(states, params, target, grid, rng):
    vals = []
    logw = []
    for g in grid:
        p2 = params.copy()
        p2[target] = float(g)
        if p2["a11"] + p2["a12"] >= 0.995 or p2["a21"] + p2["a22"] >= 0.995:
            continue
        if p2["a10"] <= 0 or p2["a20"] <= 0:
            continue
        vals.append(float(g))
        logw.append(full_loglik_given(states, p2))
    logw = np.array(logw)
    m = logw.max()
    w = np.exp(logw - m)
    w = w / w.sum()
    return float(rng.choice(np.array(vals), p=w))

def sample_e(states, which, rng):
    if which == 0:
        switches = np.sum((states[:-1] == 0) & (states[1:] == 1))
        n_i = np.sum(states[:-1] == 0)
    else:
        switches = np.sum((states[:-1] == 1) & (states[1:] == 0))
        n_i = np.sum(states[:-1] == 1)
    return float(beta_dist.rvs(2 + switches, 20 + n_i - switches, random_state=rng))

def unconditional_var(a0_i, a1_i, a2_i):
    denom = max(1e-6, 1.0 - a1_i - a2_i)
    return a0_i / denom

def relabel_by_variance(states, params):
    var1 = unconditional_var(params["a10"], params["a11"], params["a12"])
    var2 = unconditional_var(params["a20"], params["a21"], params["a22"])
    if var1 <= var2:
        return states, params
    swapped = params.copy()
    swapped["beta1"], swapped["beta2"] = params["beta2"], params["beta1"]
    swapped["a10"], swapped["a20"] = params["a20"], params["a10"]
    swapped["a11"], swapped["a21"] = params["a21"], params["a11"]
    swapped["a12"], swapped["a22"] = params["a22"], params["a12"]
    swapped["e1"], swapped["e2"] = params["e2"], params["e1"]
    return 1 - states, swapped

def run_gibbs_sampler(r, n_iter=80, burn=30, subset=None, seed=20260610):
    rng = np.random.default_rng(seed)
    states = (np.abs(r) > np.quantile(np.abs(r), 0.65)).astype(int)
    params = {
        "beta1": -0.2,
        "beta2": 0.8,
        "a10": 1.5,
        "a11": 0.84,
        "a12": 0.08,
        "a20": 3.0,
        "a21": 0.80,
        "a22": 0.12,
        "e1": 0.10,
        "e2": 0.08,
    }
    alpha_draws = []
    beta_draws = []
    state_prob_sum = np.zeros(T)
    for it in range(n_iter):
        h, a, _ = forward_recursion(states, params)
        params["beta1"] = sample_beta(states, h, params, 0, rng)
        params["beta2"] = sample_beta(states, h, params, 1, rng)
        params["a10"] = sample_alpha_grid(states, params, "a10", np.linspace(0.2, 8.0, 50), rng)
        params["a11"] = sample_alpha_grid(states, params, "a11", np.linspace(0.72, 0.95, 46), rng)
        params["a12"] = sample_alpha_grid(states, params, "a12", np.linspace(0.01, 0.28, 46), rng)
        params["a20"] = sample_alpha_grid(states, params, "a20", np.linspace(0.5, 8.0, 50), rng)
        params["a21"] = sample_alpha_grid(states, params, "a21", np.linspace(0.65, 0.96, 46), rng)
        params["a22"] = sample_alpha_grid(states, params, "a22", np.linspace(0.01, 0.28, 46), rng)
        params["e1"] = sample_e(states, 0, rng)
        params["e2"] = sample_e(states, 1, rng)
        h, a, _ = forward_recursion(states, params)
        positions = range(T) if subset is None else np.sort(rng.choice(T, size=subset, replace=False))
        for t in positions:
            logps = []
            candidate_cache = []
            for s in [0, 1]:
                cand = states.copy()
                cand[t] = s
                h_new, a_new, ll_suffix = suffix_loglik(int(t), cand, params, h, a)
                logps.append(ll_suffix)
                candidate_cache.append((cand, h_new, a_new))
            m = max(logps)
            probs = np.exp(np.array(logps) - m)
            probs = probs / probs.sum()
            pick = int(rng.choice([0, 1], p=probs))
            states, h, a = candidate_cache[pick]
        states, params = relabel_by_variance(states, params)
        if it >= burn:
            alpha_draws.append([params[k] for k in ["a10", "a11", "a12", "a20", "a21", "a22"]])
            beta_draws.append([params[k] for k in ["beta1", "beta2", "e1", "e2"]])
            state_prob_sum += states
    posterior_alpha = pd.DataFrame(alpha_draws, columns=["alpha10", "alpha11", "alpha12", "alpha20", "alpha21", "alpha22"])
    posterior_other = pd.DataFrame(beta_draws, columns=["beta1", "beta2", "e1", "e2"])
    state2_prob = state_prob_sum / max(n_iter - burn, 1)
    return posterior_alpha, posterior_other, state2_prob

# %%
posterior_alpha, posterior_other, state2_prob = run_gibbs_sampler(r, n_iter=80, burn=30, subset=None, seed=20260610)
posterior_alpha.describe().T
# Out:
#          count      mean       std       min       25%       50%       75%  \
# alpha10   50.0  3.924898  1.836500  0.677551  2.587755  4.259184  5.293878
# alpha11   50.0  0.790636  0.049637  0.720000  0.755778  0.789000  0.812000
# alpha12   50.0  0.036160  0.028005  0.010000  0.016000  0.025000  0.050500
# alpha20   50.0  4.990816  1.163467  3.102041  4.173469  4.785714  5.818878
# alpha21   50.0  0.889871  0.026248  0.815333  0.877333  0.894556  0.904889
# alpha22   50.0  0.087640  0.022200  0.046000  0.076000  0.082000  0.094000
#
#               max
# alpha10  6.885714
# alpha11  0.898889
# alpha12  0.118000
# alpha20  8.000000
# alpha21  0.939333
# alpha22  0.142000

# %%
fig, axes = plt.subplots(2, 3, figsize=(12, 7))
for ax, col in zip(axes.ravel(), posterior_alpha.columns):
    ax.hist(posterior_alpha[col], bins=12, color="lightgray", edgecolor="white")
    ax.set_title(col)
    ax.grid(True, alpha=0.2)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### (a) 結果說明
#
# Gibbs sampling 的結果顯示，各 volatility parameters 已呈現一定程度的後驗集中現象。整體而言，兩個 regime 在波動參數上存在差異，表示 GE 月報酬資料具有 regime-switching 的波動結構。

# %% [markdown]
# ## (b) State 2 的後驗分布
#
# 根據 Gibbs draws 中各期狀態屬於 regime 2 的比例，可近似 state 2 的後驗機率：
#
# $P(s_t = 2 \mid r_1, \ldots, r_T)$
#
# 以下將此機率依時間作圖，以對應投影片 page 68 底部圖形的概念。

# %%
state2_prob_series = pd.Series(state2_prob, index=ge_df.index)

plt.figure(figsize=(12, 4))
plt.plot(state2_prob_series.index, state2_prob_series.values, color="darkorange")
plt.title("Posterior probability of state 2")
plt.xlabel("Date")
plt.ylabel("P(state = 2 | data)")
plt.ylim(-0.02, 1.02)
plt.grid(True)
plt.show()

# %% [markdown]
# ### (b) 結果說明
#
# State 2 的後驗機率會隨時間明顯變動，顯示樣本期間內的市場狀態並非固定不變，而是在兩個 regime 之間切換。這支持使用 Markov switching model 來描述 GE 月報酬資料。

# %% [markdown]
# ## (c) Frequentist / EM benchmark（Baum-Welch 類方法）
#
# Bayesian Gibbs sampling 之外，也可以從 frequentist 角度估計 regime-switching model。這裡使用 `statsmodels` 的 `MarkovRegression` 建立兩狀態模型，並以 EM 初始化後再進行極大概似估計。雖然這不是完整的 Markov switching GARCH-M 同規格模型，但可作為 Baum-Welch / EM 類估計的 benchmark。

# %%
markov_mod = MarkovRegression(ge_df["r"], k_regimes=2, trend="c", switching_variance=True)
markov_res = markov_mod.fit(em_iter=20, search_reps=10, disp=False)

print(markov_res.summary())
# Out:
# c:\Users\allen\AppData\Local\Programs\Python\Python314\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
#                         Markov Switching Model Results
# ...
# Dep. Variable:                      r   No. Observations:                  888
# Model:               MarkovRegression   Log Likelihood               -2967.197
# Date:                Wed, 10 Jun 2026   AIC                           5946.394
# Time:                        23:32:58   BIC                           5975.127
# Sample:                    01-01-1926   HQIC                          5957.377
#                          - 12-01-1999
# Covariance Type:               approx
#                              Regime 0 parameters
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### (c) 結果說明
#
# Frequentist / EM benchmark 的結果顯示，兩個 regime 的變異數差異明顯，其中一個 regime 對應較低波動，另一個 regime 對應較高波動。轉移機率亦顯示狀態具有一定持續性，因此 benchmark 結果同樣支持資料中存在 regime-switching 現象。

# %% [markdown]
# ## (d) 各期 inferred states
#
# 根據 (b) 所得到的 state 2 後驗機率，若某一期 $P(s_t=2\mid data) > 0.5$，則將其判定為 state 2；否則判定為 state 1。

# %%
inferred_state = pd.Series((state2_prob_series > 0.5).astype(int) + 1, index=ge_df.index)

plt.figure(figsize=(12, 4))
plt.step(inferred_state.index, inferred_state.values, where="mid", color="purple")
plt.title("Inferred states over time")
plt.xlabel("Date")
plt.ylabel("State")
plt.yticks([1, 2])
plt.grid(True)
plt.show()

inferred_state.head()
# Out:
# date
# 1926-01-01    1
# 1926-02-01    1
# 1926-03-01    1
# 1926-04-01    1
# 1926-05-01    1
# dtype: int64

# %% [markdown]
# ### (d) 結果說明
#
# 根據後驗機率所推論的 state path，可看出資料在樣本期間內確實發生狀態切換。不過，部分時段切換較頻繁，因此本圖較適合用來呈現整體 regime 轉換趨勢，而不宜過度解讀單一月份的狀態判定。

# %% [markdown]
# # Problem 3：VAR model and Cointegration
#
# 本題使用 `Dataset-InterestRate.txt`，資料內容為美國月資料的 1-year 與 3-year Treasury constant maturity rates，樣本期間為 1953 年 4 月至 2004 年 3 月。
#
# 本題將依序完成以下工作：
#
# 1. 對二維資料 $(r_{1t}, r_{3t})$ 建立 VAR 模型。
# 2. 在 5% 顯著水準下檢查 VAR 模型是否足夠合理。
# 3. 檢驗兩個利率序列是否存在共整合關係，並說明其數學意義。

# %%
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.vector_ar.vecm import coint_johansen

ir_path = r"c:\Users\allen\OneDrive\Desktop\研究所\時序\Dataset-InterestRate.txt"
ir_df = pd.read_csv(ir_path, sep=r"\s+", header=None, names=["r1", "r3", "year", "month", "day"])
ir_df["date"] = pd.to_datetime(dict(year=ir_df["year"].astype(int), month=ir_df["month"].astype(int), day=1))
ir_df = ir_df.set_index("date")[["r1", "r3"]]

print("資料筆數：", ir_df.shape[0])
print("缺失值個數：")
print(ir_df.isna().sum())
print("\n描述統計量：")
print(ir_df.describe())
ir_df.head()
# Out:
# 資料筆數： 612
# 缺失值個數：
# r1    0
# r3    0
# dtype: int64
#
# 描述統計量：
#                r1          r3
# count  612.000000  612.000000
# mean     5.801193    6.214395
# std      3.008098    2.863937
# min      0.820000    1.470000
# 25%      3.595000    4.040000
# 50%      5.515000    5.890000
# 75%      7.400000    7.740000
# max     16.720000   16.220000
#               r1    r3
# date
# 1953-04-01  2.36  2.51
# 1953-05-01  2.48  2.72
# 1953-06-01  2.45  2.74
# 1953-07-01  2.38  2.62
# 1953-08-01  2.28  2.58

# %% [markdown]
# ## (a) 配適 VAR 模型
#
# 先利用 lag order selection 比較不同落後期數的 AIC、BIC 與 HQIC。

# %%
var_model = VAR(ir_df)
lag_selection = var_model.select_order(12)
print(lag_selection.summary())

var_res = var_model.fit(3)
print(var_res.summary())
# Out:
#  VAR Order Selection (* highlights the minimums)
# ...
#        AIC         BIC         FPE         HQIC
# --------------------------------------------------
# 0       0.7845      0.7992       2.191      0.7902
# 1       -5.643      -5.599    0.003542      -5.626
# 2       -5.829      -5.756    0.002941      -5.801
# 3       -5.891     -5.788*    0.002764      -5.851
# 4       -5.908      -5.776    0.002717      -5.857
# 5       -5.905      -5.744    0.002725      -5.843
# 6       -5.918      -5.728    0.002690      -5.844
# 7       -5.981      -5.762    0.002525     -5.896*
# 8       -5.980      -5.731    0.002529      -5.883
# 9       -5.986      -5.707    0.002514      -5.877
# 10      -6.002      -5.695    0.002473      -5.883
# 11      -5.995      -5.658    0.002491      -5.864
# 12     -6.003*      -5.636   0.002472*      -5.860
# --------------------------------------------------
#   Summary of Regression Results
# ...
# Model:                         VAR
# ...

# %% [markdown]
# ### (a) 簡短結論
#
# 根據 lag order selection，AIC 與 BIC 對最佳落後期數的建議不同。為兼顧模型簡潔性與可解釋性，本研究採用 BIC 所選出的 **VAR(3)** 作為後續分析模型。

# %% [markdown]
# ## (b) VAR 模型 adequacy 檢查
#
# 為檢查配適後的 VAR 模型是否合理，可從下列幾個方向進行：
#
# 1. **Stability**：檢查模型是否穩定。
# 2. **Residual autocorrelation**：利用 Portmanteau / whiteness test 檢查殘差是否仍有自相關。
# 3. **Normality**：檢查殘差是否接近常態分配。
#
# 題目要求在 5% 顯著水準下進行判斷。

# %%
print("VAR(3) 是否穩定：", var_res.is_stable())
print("\nWhiteness test:")
print(var_res.test_whiteness(nlags=24))
print("\nNormality test:")
print(var_res.test_normality())
# Out:
# VAR(3) 是否穩定： True
#
# Whiteness test:
# <statsmodels.tsa.vector_ar.hypothesis_test_results.WhitenessTestResults object. H_0: residual autocorrelation up to lag 24 is zero: reject at 5% significance level. Test statistic: 285.393, critical value: 106.395>, p-value: 0.000>
#
# Normality test:
# <statsmodels.tsa.vector_ar.hypothesis_test_results.NormalityTestResults object. H_0: data generated by normally-distributed process: reject at 5% significance level. Test statistic: 2267.800, critical value: 9.488>, p-value: 0.000>

# %% [markdown]
# ### (b) 簡短結論
#
# VAR(3) 模型通過穩定性檢查，但在 5% 顯著水準下，殘差 whiteness test 與 normality test 皆拒絕虛無假設，表示殘差仍存在自相關且不符合常態，因此此 VAR 模型不能視為完全充分的配適。

# %% [markdown]
# ## (c) 共整合檢定
#
# 若兩個序列本身皆為非平穩，但存在某個線性組合為平穩序列，則稱這兩個序列 **cointegrated**。數學上，若 $r_{1t}$ 與 $r_{3t}$ 皆為 $I(1)$，但存在非零向量 $\beta$ 使得：
#
# $\beta_1 r_{1t} + \beta_2 r_{3t}$
#
# 為平穩序列，則稱兩序列具有共整合關係。
#
# 本題先檢查各序列是否為 $I(1)$，再利用 **Johansen cointegration test** 在 5% 顯著水準下檢驗共整合秩。

# %%
for col in ir_df.columns:
    level_p = adfuller(ir_df[col])[1]
    diff_p = adfuller(ir_df[col].diff().dropna())[1]
    print(f"{col} level ADF p-value: {level_p:.6f}")
    print(f"{col} first-difference ADF p-value: {diff_p:.6f}\n")

johansen_res = coint_johansen(ir_df, det_order=0, k_ar_diff=2)
print("Trace statistics:", johansen_res.lr1)
print("Trace 95% critical values:", johansen_res.cvt[:, 1])
print("Max-eigen statistics:", johansen_res.lr2)
print("Max-eigen 95% critical values:", johansen_res.cvm[:, 1])
print("\nCointegrating vectors:")
print(johansen_res.evec)
# Out:
# r1 level ADF p-value: 0.246671
# r1 first-difference ADF p-value: 0.000000
#
# r3 level ADF p-value: 0.272350
# r3 first-difference ADF p-value: 0.000000
#
# Trace statistics: [30.81095744  3.70319258]
# Trace 95% critical values: [15.4943  3.8415]
# Max-eigen statistics: [27.10776486  3.70319258]
# Max-eigen 95% critical values: [14.2639  3.8415]
#
# Cointegrating vectors:
# [[ 1.99815165 -0.26929407]
#  [-2.0156816   0.6278198 ]]

# %% [markdown]
# ### (c) 結論
#
# ADF 檢定顯示 `r1` 與 `r3` 在 level 上皆無法拒絕單根，但在一階差分後皆為平穩，因此可視為 $I(1)$ 序列。Johansen test 在 5% 顯著水準下支持存在 **一條共整合關係**，表示 1-year 與 3-year interest rates 雖然各自非平穩，但兩者之間存在長期均衡關係。
